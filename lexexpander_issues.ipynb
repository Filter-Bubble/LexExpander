# %%
import LexExpander
from CachedEmbedding import CachedEmbedding
import random
import sys
import pandas as pd
from tqdm import tqdm
from contextlib import redirect_stdout

# %%
# Filepaths
# EMBEDDINGFILE = "/home/dafne/shared/FilterBubble/word-embeddings/fasttext.model.bin"
EMBEDDINGFILE = "/home/dafne/shared/FilterBubble/word-embeddings/fasttext.model50.bin"
issue_file = "/home/dafne/shared/FilterBubble/issue-positions/issues-queries.csv"

# %%
# Load issue file
issues_df = pd.read_csv(issue_file)
issues_df.parentI.value_counts()
# Out:
# klimaatMilieu          112
# ondernemingsklimaat     71
# Infrastructuur          69
# ontwikkelingCrim        66
# coronabestrijding       65
# OenW                    65
# geZorg                  61
# socZek                  56
# belastHeffing           53
# bestrijdingCrim         45
# integratie              35
# vrijheidsrechten        29
# werk                    25
# coronaverspreiding      25
# EuropeseUnie            24
# normenWaarden           22
# begrotingssaldo         20
# woning                  18
# terreurbestrijding      14
# bestVernieuw            13
# ontwikHulp              12
# infrastructuur           1
# Name: parentI, dtype: int64

# %%
issues_df.head()
# Out:
#              queryIssue directI          parentI gparentI parentA gparentA  \
# 0          aardgasbaten     pos  begrotingssaldo    issue     NaN      NaN
# 1        ambtenarensal*     neg  begrotingssaldo    issue     NaN      NaN
# 2  begrotingsdiscipline     pos  begrotingssaldo    issue     NaN      NaN
# 3        begrotingsnorm     pos  begrotingssaldo    issue     NaN      NaN
# 4   begrotingsoverschot     pos  begrotingssaldo    issue     NaN      NaN
#
#   zoek1  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10
# 0   NaN         NaN         NaN         NaN          NaN
# 1   NaN         NaN         NaN         NaN          NaN
# 2   NaN         NaN         NaN         NaN          NaN
# 3   NaN         NaN         NaN         NaN          NaN
# 4   NaN         NaN         NaN         NaN          NaN

# %%
lexicons = dict(issues_df.groupby('parentI').queryIssue.agg(list))
# Some filtering and cleaning
lexicons = {issue: [query.replace('*','').replace(' ','_') for query in lex] 
            for issue, lex in lexicons.items()
           if len(lex)>1}

# %%
# example:
lexicons['ontwikHulp']
# Out:
# ['artsen_zonder_grenzen',
#  'cordaid',
#  'dekolonisatie',
#  'derde_wereld',
#  'ICTO',
#  'kolonialisme',
#  'noodhulp',
#  'ontwikkelingsh',
#  'ontwikkelingslanden',
#  'ontwikkelingsorg',
#  'ontwikkelingss',
#  'unicef']

# %%
# Load embedding
embedding_model = CachedEmbedding(EMBEDDINGFILE, embedding_style="fasttext")
embedding_model.prepare()

# %%
# Define some parameters for tuning
sample_size = 3
new_topn_to_draw_from = 10

# %%
expanded_lexicon = {}

for issue, lexicon in tqdm(lexicons.items()): #[('ontwikHulp', lexicons['ontwikHulp'])]:
    print('Issue {}'.format(issue))
    
    logging_file = '{}.log.txt'.format(issue)
    my_expander = LexExpander.LexExpander(lexicon_iterable = lexicon,
                                      embedding_model = embedding_model,
                                      sample_size = sample_size,
                                      new_topn_to_draw_from = new_topn_to_draw_from
                                        )
    my_expander.prepare(verbose=True)
    print("Running algorithm..")
    seed_set = random.sample(my_expander.loaded_lex_as_set, 5)
    with open(logging_file, 'w') as logout:
        with redirect_stdout(logout):
            my_expander.run(sample="random",given_sampling_population=seed_set)
    expanded_lexicon[issue] = (my_expander.added_to_lexicon, my_expander.given_lexicon_set_WEAK)
    print("Done")
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
# Issue EuropeseUnie
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#   5%|▍         | 1/21 [00:11<03:58, 11.94s/it]
# Done
# Issue Infrastructuur
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#  10%|▉         | 2/21 [00:20<03:10, 10.01s/it]
# Done
# Issue OenW
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#  14%|█▍        | 3/21 [00:30<03:02, 10.13s/it]
# Done
# Issue begrotingssaldo
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#  19%|█▉        | 4/21 [00:41<02:57, 10.47s/it]
# Done
# Issue belastHeffing
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#  24%|██▍       | 5/21 [00:51<02:40, 10.03s/it]
# Done
# Issue bestVernieuw
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#  29%|██▊       | 6/21 [00:59<02:19,  9.32s/it]
# Done
# Issue bestrijdingCrim
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#  33%|███▎      | 7/21 [01:04<01:54,  8.17s/it]
# Done
# Issue coronabestrijding
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#  38%|███▊      | 8/21 [01:11<01:39,  7.65s/it]
# Done
# Issue coronaverspreiding
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#  43%|████▎     | 9/21 [01:17<01:26,  7.25s/it]
# Done
# Issue geZorg
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#  48%|████▊     | 10/21 [01:26<01:24,  7.64s/it]
# Done
# Issue integratie
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#  52%|█████▏    | 11/21 [01:33<01:14,  7.44s/it]
# Done
# Issue klimaatMilieu
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#  57%|█████▋    | 12/21 [01:43<01:14,  8.30s/it]
# Done
# Issue normenWaarden
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#  62%|██████▏   | 13/21 [01:51<01:04,  8.06s/it]
# Done
# Issue ondernemingsklimaat
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#  67%|██████▋   | 14/21 [02:00<00:58,  8.39s/it]
# Done
# Issue ontwikHulp
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#  71%|███████▏  | 15/21 [02:08<00:50,  8.41s/it]
# Done
# Issue ontwikkelingCrim
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#  76%|███████▌  | 16/21 [02:21<00:48,  9.73s/it]
# Done
# Issue socZek
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#  81%|████████  | 17/21 [02:33<00:42, 10.51s/it]
# Done
# Issue terreurbestrijding
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#  86%|████████▌ | 18/21 [02:42<00:30, 10.05s/it]
# Done
# Issue vrijheidsrechten
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#  90%|█████████ | 19/21 [02:56<00:22, 11.21s/it]
# Done
# Issue werk
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
#  95%|█████████▌| 20/21 [03:01<00:09,  9.35s/it]
# Done
# Issue woning
# reading in the lexicon ...
# setting up embeddings ...
# using passed model <CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             3 sample_size
#             10 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	None
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f43ee43b090>
#             candidates_list:	None
#
#             target_folder:	.
#
# Running algorithm..
# 100%|██████████| 21/21 [03:08<00:00,  9.00s/it]
# Done

# %%
# Print out the proposed expansions, both strong and weak

for issue in expanded_lexicon:
    print("Issue: ", issue)
    print("Existing lexicon:")
    print(', '.join(lexicons[issue]))
    print("\nNew strong:")
    print(', '.join(expanded_lexicon[issue][0]))
    print("\nNew weak:")
    print(', '.join(expanded_lexicon[issue][1]))
    print('\n-------------------------------------------------------\n')
# Out:
# Issue:  EuropeseUnie
# Existing lexicon:
# 3_procent, 60_procent, brexit, coronaherstelfonds, ECB, EMA, EU, europarlementarier, Europe_Parlement, Europees_Medicijn_Agentschap, Europese_Centrale_Bank, Europese_Commissie, Europese_regeringsleiders, Europese_Unie, euroscep, eurozone, geneesmiddelenbureau, herstelfonds, Hof_van_Justitie, lidstaten, medicijnagentschap, meerjarenbegroting, Nexit, raad_van_ministers
#
# New strong:
#
#
# New weak:
#
#
# -------------------------------------------------------
#
# Issue:  Infrastructuur
# Existing lexicon:
# chipkaart, airbus, AirFrance, airport, auto, automobiliteit, benzinestation, bestemmingsplan, bestemmingsverkeer, Betuwelijn, bevoorrading, Boeing, dijkverzwaring, distributie, doorvoer, Eurostar, file, glasvezel, haven, hub, infrastructu, internetprovider, KLM, laadpa, landingen, landingsba, lightrail, logisti, luchthaven, luchtvaart, mobiliteit, nachtvluchten, netwerkprovider, NS, overloopluchthaven, pakketbezorg, pakketdienst, parkeer, post, prorail, rail, Randstadrail, ruimtelijke_ordening, Schiphol, sneltram, snelweg, spoorweg, streekplan, tankstation, telefoonnetwerk, Thalys, tram, transport, trucker, vakantievluchten, verkeer, vervoer, vliegbeweging, vliegtuig, vliegverkeer, vrachtvervoer, vrachtwagen, vroem, wegen, wegenaanleg, wegennet, wegtransport, wegverbreding, werkverkeer
#
# New strong:
#
#
# New weak:
#
#
# -------------------------------------------------------
#
# Issue:  OenW
# Existing lexicon:
# aardrijkskunde, analfabe, atheneum, basisonderwijs, basisscho, beroepsopleiding, cito, colleges, curriculum, cursus, deskundige, digibe, domkop, dyslex, educatie, eindexamen, examens, expert, geschiedenisond, gymnasi, HAVO, hoogleraar, kennis, kennisland, kleuteronderwijs, leerachterstand, leergang, leerling, leerplan, leraar, leraren, lerarentekort, lessen, lesuitval, onderricht, onderwijs, onderwijzer, onderzoek, ontdekking, opleiding, professor, rekenen, rekenond, research, ROC, scholen, scholier, scholing, school, science, studie, studieachterstand, studieschuld, studie-uitval, studievertraging, studievoortgang, taalachterstand, taalonder, tentamen, thuisonderwij, uitvinding, universiteit, vinding, voortgezet_onderwijs, wetenschap
#
# New strong:
# volwasseneducatie, vakonderwijs
#
# New weak:
# onderwijscollega, leerpunten, onderwijsmeter, onderwijsvormen, vervolgonderwijs, kunstvakonderwijs, peuteronderwijs, onderwijsmethoden, hogerberoepsonderwijs, schoolcultuur, onderwijstaken, onderwijssegregatie, onderwijst, onderwijsfilosofie, vmbo, volwassenonderwijs, schoolland, onderwijsvernieuwers, onderwijsinhoudelijke, techniekonderwijs, vertrouwensleerling, schoolpraktijk, schoolser, onderwijstaak, beroepsonderwijs, onderwijsjargon, middelbaar, zwemonderwijs, schrijvenderwijs, onderwijsondersteuning, onderwijspraktijk, terugkeeronderwijs, onderwijsinspanning, onderwijsman, onderwijssoort, onderwijsmodel, onderwijstypen, schrijfonderwijs, onderwijsverslag, onderwijsgroep, dagonderwijs, thuisonderwijs, vroegschoolse, talenonderwijs, kunstonderwijs, onderwijsconcept, onderwijstaal, onderwijstraditie, basiseducatie, onderwijsvernieuwer, montessorionderwijs, volwasseneneducatie, geschiedenisonderwijs, onderwijsmethode, onderwijsveld, onderwijscultuur, iederwijs, islamonderwijs, schoolonderwijs, onderwijsachtergrond, onderwijsaanbod, taalonderwijs, praktijkonderwijs, onderwijsbegeleiding, volwassenenonderwijs, onderwijsvorm, schoolvak, iederwijsscholen, leesonderwijs, onderwijsondersteunend, daltononderwijs, onderwijstype, onderwijszaken, onderwijsdoelen, studiehuis
#
# -------------------------------------------------------
#
# Issue:  begrotingssaldo
# Existing lexicon:
# aardgasbaten, ambtenarensal, begrotingsdiscipline, begrotingsnorm, begrotingsoverschot, begrotingstekort, belastinginkomsten, belastingmeevaller, bezuiniging, budgetneutra, financieringstekort, inflatie, kaasschaaf, overheidsfinancien, overheidsschuld, overheidsuitgaven, schatkist, schuldenlast, staatsobligaties, staatsschuld
#
# New strong:
# uitgavenkaders, uitgavenmeevallers, uitgavenreserve, uitgavenplafonds, miljardenmeevallers, begrotingtekort, staatsschuldaflossing, begrotingsoverschotten, staatsschulden, inkomstenmeevaller, begrotingsgeld, uitgavenkader, uitgavengroei, belastingmeevallers, overheidstekort, meevallers, schatkisttekort, uitgavenplafond, begrotingsprobleem, uitgavenkant, inkomstenmeevallers, begrotingsmeevallers, begrotingsoverschrijdingen, begrotingssanering, begrotingsoverschrijding, uitgavenverhoging, miljardenmeevaller, overheidsbegrotingen, staatsschuldreductie, aardgasmeevallers, begrotingssaldo, financieringstekorten, begrotingsuitgaven, staatssschuld, lastenverlichting, zorguitgaven, begrotingssteun, begrotingsgat, uitgavenmeevaller, pensioenmeevaller, begrotingssaldi, staatsschuldquote
#
# New weak:
# belastingverhogingen, lastenstelsel, schuldaflossing, belastingopbrengsten, uitgavennorm, gasbaten, schuldaflossingen, koopkrachtbehoud, landsbegroting, lastenverhogingen, lastenverlaging, productbegroting, administratievelastenverlichting, belastingverzwaring, overheidsbudget, bouwbudget, lastendruk, lastenverhoging, koopkrachtreparatie, overheidsbegroting, begrotingstekorten, koopkrachtbeleid, kostenverhogingen, belastingtegenvallers, lastenverlichtingen, belastinguitgaven, uitgavenbeleid, financierinsgtekort, schuldquote, kostenverlagingen, uitgavenverhogingen, begrotings, belastingopbrengst, betalingsbalanstekorten, lastenverdeling, koopkrachtgaranties, lastenverzwaringen, lastenverlichtingspakket, overheidsschulden, miljardenuitgaven, kostenverhoging, kostenverlaging, koopkrachtmaatregelen, lastenvermindering, lastenverzwaring, overheidsuitgave, inkomensmeevallers, lastenmaximering, belastingmaatregelen, begrotingsevenwicht, belastingverhoging, begrotingsrust, lastenverlichtende, overheidstekorten, lastenverlagingen, rentemeevallers, belastingvermindering, eubegroting, inkomstenverlies
#
# -------------------------------------------------------
#
# Issue:  belastHeffing
# Existing lexicon:
# belasting, accountant, afvalstoffenheffing, belasting, belastingaangifte, belastingadviseur, belastingafdracht, belastingaftrek, belastingconstructie, belastingdruk, belastingen, belastingfraude, belastingheffing, belastinginning, belastingontduiking, belastingontwijking, belastingopbrengsten, belastingparadij, belastingpremie, belastingruling, belastingtarie, belastinguitstel, belastingverhoging, belastingverlaging, belastingvlucht, brievenbusfirma, btw, digitaks, dividendbelasting, fiscus, forfait, heffing, heffingskorting, inkomensbelasting, kapitaalvlucht, klimaattaks, lasten, lastendruk, loonbelasting, loonheffing, naheffing, ontduik, ontwijk, premieopslag, ruling, taks, trustkantoor, trustsector, verhuurderheffing, vermogensbelasting, vermogenswinstbelasting, vliegtaks, witwassen
#
# New strong:
# kapitaalsbelasting, omzetbelasting, heffingskortingen, inkomstenbelasting, belastinglatentie, belastingkosten, solidariteitsbelasting, belastingeuro, belastingdeal, inkomstenbelastingtarieven, belastingplichtig, belastingteruggaven, lastenaftrek, inkomstenbelastingtarief, belastingderving, arbeidskostenforfait, belastingdeel, belastingteruggaaf, successiebelasting, vennootsschapsbelasting, goedbelasting, spaarbelasting, loonbelastingsysteem, inkomenstenbelasting, premieheffing, belastingvoordeel, kostenaftrek, belastingvoordeeltjes, aftrekpost, toptarief, belastingnaheffing, aftrekposten, belastingrekening, premieaftrek, belastingteruggave, bedrijfsbelasting, schenkingsbelasting, belastingtarieven, voorheffingssaldo, afdrachtskorting, erfenisbelasting, belastingjaar, inkomstenbelastingen, belastingtarief, vennootschapsbelasting, vermogensheffing
#
# New weak:
# heffingstarief, arbeidskorting, belastingdouceurtjes, weeldebelasting, winstbelastingen, huurbelasting, inkomenscompensatie, zorgtoeslag, kapitaalbelasting, belastingpeil, belastinglast, zorgkorting, belastingconsulent, belastingregel, belastingvordering, basisaftrek, premiedeel, belastingbedrag, belastingvoordeeltje, reiskostenaftrek, belastingopbrengst, belastingafspraken, vermogensrendementsbelasting, zorgtoeslagen, belastingkortingen, belastingvorderingen, precariobelasting, inkomenstoeslagen, belastingzaak, vermogensrendementsheffing, personenbelasting, belastingbetalingen, belastingdollars, pensioenpremieaftrek, belastingcompensatie, premieplicht, houderschapsbelasting, belastingvrijstelling, inkomstenbelastingfraude, rijksbelasting, belastingnadeel, tonnagebelasting, belastingpenningen, overdrachtsbelasting, belastingvrijstellingen, belastingafdrachten, inkomenstoeslag, vennootschapsbelastingdruk, huisbelasting, ouderenaftrek, belastingdeurwaarders, eindheffing, rendementsheffing, belastingbate, inkomensafhankelijk, inschrijvingsbelasting, aftrekbedrag, belastingbox, inkomensschaal, belastingservice, huurwaardeforfait, inkomensafhankelijke, belastingsubsidie, beroepskostenaftrek, retourprovisie, belastingdouceurtje, loonheffingen, belastingdienst, verrekenbedingen, verrekenbeding, belastingplicht, zorgbelasting, heffings, belastingsubsidies, belastingkorting, zorgpremie, verrekening, vennootschapsbelastingtarief, belastingvoeten, luxebelasting, assurantiebelasting, belastingbesparing, winstbelastingtarief, inkomensaanvulling
#
# -------------------------------------------------------
#
# Issue:  bestVernieuw
# Existing lexicon:
# burgerberaad, burgertop, democrati, districtenstelsel, gekozen_burgemeester, gekozen_premier, inspraak, Navalny, openbaarheid, referenda, referendum, volksraadpleging, WOB
#
# New strong:
# volksraadspleging, partijreferendum, referendumdebat, scholierenreferendum, kieswet, referendums, volksraad, referendumcomite, volksinitiatief, grondwetswijzingen, plebisciet, ontwerpgrondwet, grondwetreferenda, grondwetswijziging, grondwetdiscussie, grondwetszaken, grondwetsartikel, onafhankelijkheidsreferendum, grondwetsbepaling, grondwetswijzing, grondwetscommissie, wetgevingsreferendum, volksstemming, grondwetreferendum, grondwetcommissie, parlementsbesluit, volksreferendum, conceptgrondwet, referendumwijzer, referendumwet, grondwetstekst, referendumstrijd, grondwetsdiscussie, referendumuitslag, vredesreferendum, referendumvoorstel, assemblee, grondwetsherziening, volksraadplegingen, grondwetsontwerp, kernparlement, grondwetsherzieningen, referendumcampagne, eugrondwet, euroreferendum, ledenreferendum, grondwetsvoorstel, referendumplannen, referendumcrisis, referendumverzoek, grondwetswijzigingen, grondwetsreferendum, referendumplan, referendumland, referendumvraag, referendumpartij, unieparlement
#
# New weak:
# stemmenweging, constitutie, burgemeestersreferendum, grondwettelijke, kiezersuitspraak, parlement, grondwettelijkheid, volksuitspraak, grondwetverdrag, overgangsparlement, grondwettige, stadsparlement, grondwetgever, parlements, meerderheidsbesluit, parlementsmeerderheid, ledenparlement, grondwettig, grondwetten, grondwetsverdrag, grondwet, grondwetshervorming, verkiezingswetten, stemmenverdeling, volksvertegenwoordiging, grondwetshervormingen, grondwettelijk, grondwetgevende, grondwettekst, referendumverordening, partijparlement, wetsontwerp, kiesstelsel, stembusakkoord, grondwettigheid, coalitieverdrag, deelparlement
#
# -------------------------------------------------------
#
# Issue:  bestrijdingCrim
# Existing lexicon:
# aangehouden, aanhouden, aanhouding, afstraff, agent, AIVD, arrestatie, bekeuren, bekeuring, bestraff, Boa, bodycam, boete, crimefighter, dienstwapen, dwangverpleging, Europol, gebiedsverbod, gevangenis, geweer, gummiknuppel, handboeien, infiltrat, inlichtingenplicht, korpschef, legitimatieplicht, marechaussee, ME, MIVD, mobiele_eenheid, opgepakt, oppakken, oproerpolitie, opsporing, partnertoets, pepperspray, politie, rechtshandhaving, straf, TBS, traangas, verbalise, wapenstok, waterkanon, wijkagent
#
# New strong:
# proeftijd, taakstraf, doodsstraf, ontzegging, rijbevoegdheid, geldboete, ontzeggingen, werkstraf, rijontzegging, werkstraffen, voorwaardelijk
#
# New weak:
# gevangensstraf, uitgezeten, geldboetes, celstraf, vrijspraak, maximumstraffen, jeugdstraffen, vrijheidsstraf, jeugddetentie, levenslangen, gevangenisstraffen, cel, levenslang, vrijspreken, strafeisen, strafverminderende, voorwaardelijke, veroordeeld, maximumstraf, voorhechtenis, maximumcelstraf, levenslange, strafeis, celstraffen, tuchtstraf, vrijsprak, voorarrest, straffen, gevangenhouding, uitzitten, vrijheidsstraffen, uitzat, strafvermindering, veroordeel, hechtenis, gevangenisstraf, voorwaardelijkheid, minimumstraf, vergrijp, geeist, langgestrafte, invrijheidstelling, taakstraffen
#
# -------------------------------------------------------
#
# Issue:  coronabestrijding
# Existing lexicon:
# 5G-masten, afstand, anderhalve, Astrazenica, avondklok, beperkend, beschermingsmiddel, Biontech, bloedspoed, café_dicht, café_open, code_zwart, complot, corona_app, coronabeleid, coronamaatregel, coronamelder, coronanoodwet, coronarichtlijn, coronatest, coronavaccin, desinfect, elleboog, handen_wassen, horeca_dicht, horeca_open, huisfeest, illegale_huisfeest, inent, ingrijpend, Janssen, Landelijk_Netwerk_Acute Zorg, lockdown, Moderna, mondkap, mondmasker, Nederlandse_Vereniging_van_Ziekenhuizen, OMT, overheidsingrijpen, Pfizer, prikken, priklocaties, red_team, regels, restaurant, scholen_dicht, sluit, sneltest, soepel, Spoetnik, telewerk, testbeleid, testen, testlocatie, teststraat, thuiswerk, vaccin, vaccinontwikkelaars, versoepel, virusregels, Viruswaanzin, Viruswaarheid, was_je_handen, winkels_dicht, winkels_open
#
# New strong:
#
#
# New weak:
#
#
# -------------------------------------------------------
#
# Issue:  coronaverspreiding
# Existing lexicon:
# 5G, aerosolen, besmett, bezoek, Braziliaanse_variant, Britse_variant, corona, coronabesmet, coronabrandhaard, coronacrisis, coronageval, coronapatiënt, coronavirus, Covid19, derde_golf, eerste_golf, epidemie, mutatie, pandemie, patiënt, tweede_golf, uitbraak, verspreiding, virus, Zuidafrikaanse_variant
#
# New strong:
# rhinovirus
#
# New weak:
# adenovirus, norovirussen, hmpv, poliovirus, rotavirus, paramyxovirus, influenzavirussen, vogelinfluenzavirus, influenzavirus, herpesvirus, coronavirussen, retrovirus, cytomegalovirus, affluenza, papillomavirus, hartworm, hantavirus, myxomatose, norovirus, ebolavirus
#
# -------------------------------------------------------
#
# Issue:  geZorg
# Existing lexicon:
# ambulance, AMC, apothe, arts, bedden, bedlegerig, behandeling, biomedical, chemoku, collectiviteitskorting, dokter, doodziek, drogist, eerste_hulp, eigen_risico, embryo, gehandicapteninstelling, geneeswijze, genetische_mod, gentherapie, gezondheid, GGD, huisarts, hulpverlene, IC, intensive_care, internist, jeugdzorg, kinderarts, ligduur, longarts, mantelzorg, MC, medicijn, medisch, Nederlandse_zorgautoriteit, NZa, patient, piek, psychiatrisiche_kliniek, slachtofferhulp, Spoedeisende_Hulp, stamcel, thuiszorg, verple, verzekering, verzorgingshui, virolo, volksgezondheidscrisis, volkskgezondheid, wachtlijsten, wachttijd, ziek, zieken, ziekenhui, ziekte, ziektekosten, ziektekostenpremie, ziektekostenverz, zorg, zuurstof
#
# New strong:
#
#
# New weak:
# uurszorg, basiszorg
#
# -------------------------------------------------------
#
# Issue:  integratie
# Existing lexicon:
# allochto, Antifa, artikel_1, asieladvocaat, asielzoeker, AZC, bootvluchtel, buitenlander, discrimin, diversiteitsbeleid, etnische_profilering, gelukszoeker, I_cannot_breathe, illegalen, immigrant, immigratie, inburgering, marokk, migra, multiculture, Schengen, slavernijverleden, statushoud, Syri, Turkijedeal, Turks, uitgeprocedeerd, uitheems, uitzetting, van_kleur, veiligelanders, verblijfspapier, verblijfsvergunning, vluchtel, vreemdeling
#
# New strong:
# uitgeprocedeerden, asielzoekersopvang, asielzoekercentra, asielzoekerskinderen, geprocedeerd, asielzoekers, geprocedeer, asielzoekertje, asielzoekende, asielzoekster, asiels, asielzoeksters, exasielzoekers, asielzoekertjes, asielkinderen, uitgeprocedeerde, asielgezinnen, asielzoekersgezinnen, asielen, asielzoekersstroom
#
# New weak:
# asielzoekersboot, asielzoekersgezin, doorgeprocedeerd, asiel, asielcentra, verblijfsstatussen, asielopvang, asielzoekersstop, asielaanvragers, asielverzoekers, asielcentrum, asielzoekercentrum, asielaanvraag, terugkeervisum, asielpardon, asielverzoek, vertrekcentra, asielmigranten, vreemdelingenbewaring, vreemdelingendetentie, opvangland, vluchteling, vreemdelingen, vluchtelingenwet, vluchtelingenpaspoort, vluchtelingenstatus, uitzettingscentra, uitzettingen, asielzoekersprobleem, asielaanvrager, asielzoekerscentra
#
# -------------------------------------------------------
#
# Issue:  klimaatMilieu
# Existing lexicon:
# aardgas, aardgascentrale, afvalberg, afvalscheiding, ammoniak, antibiotica, bijensterfte, bioboer, biodiversiteit, biogascentrale, biologische_landbouw, biomassa, blockchain, bodemverontreiniging, bodemvervuiling, boerenprotest, bosbrand, bossen, broeikasgas, CO2, dierenwelzijn, droogte, duurza, ecologi, ecosysteem, electiricitetsgebruik, elektriciteitsverbruik, elektrische_auto, energiebesparing, energielabel, energieneutra, energiepark, energiestrategie, energiezuinig, fietspad, fijnstof, geluidshinder, geluidsoverlast, gerecycle, glysofaat, grutto, hergebruik, kerncentrale, klimaat, klimaatafspra, klimaatakkoord, klimaatbeleid, klimaatdoel, klimaatmaatre, klimaatverandering, kolencentrale, kringlooplandbouw, landbouwgif, luchtverontreiniging, luchtvervuiling, luchtwasser, maximumsnelheid, mestoverschot, milieubeh, milieubeweging, milieuverontreiniging, milieuvoorschrift, molens, natura, natuurbeh, natuurbescherming, natuurgebied, natuurherstel, onkruidbestrijd, openbaar_vervoer, opwarming, OV_, OV_jaarkaart, overstroming, ozonlaag, permafrost, pesticide, pfas, plastic, radioactie, recycl, scooter, smelt, smeltende_ijskap, snelfietspad, stikstofdepositie, stikstofdioxide, stikstofneerslag, stikstofoxide, stikstofuitstoot, stiltegebied, temperatuurstijging, trein, treinverbinding, turbines, uitlaatgassen, uitstoot, Urgenda, veenbrand, verduurza, vervuil, vuilstort, warmtepomp, waterstofcentrale, weidevogels, windmolen, windturbine, zeespiegelstijging, zonne-energie, zonnepane, zonnepark, zonneweide
#
# New strong:
# verontreinigingen, olievervuiling, olievervuilingen, dioxinevervuiling, verontreinigd, verontreinigende, olieverontreiniging, asbestverontreiniging, bodemverontreinigingen, lozingen, verontreinigen, verontreinigend, vervuilingen, verontreinigde, verontreiniging, grondwaterwet, milieurampen, verontreinigt, watervervuiling, milieuvervuiling, milieucatastrofe, waterverontreiniging, lozing, asbestvervuiling, milieuschade, vervuiling, zeevervuiling, grondwateronttrekkingen, bodemberoering, lichtvervuiling, riooloverstorten, milieuschadelijke, grondwateroverlast, horizonvervuiling, benzeenvervuiling, riooloverstort, vervuild, luchtverontreinigende, milieuverontreinigende
#
# New weak:
# wateroverlast, ammoniaklucht, watertekort, propachloor, afvalverbranding, afvalstoffen, milieuoverlast, milieudelicten, gifstroom, grondwaterniveau, zwaveldioxine, milieudruk, zeemilieu, overbegrazing, bodemlagen, ontgassen, wateronttrekking, milieulast, klimaatverstoring, bruinkoolwinning, ammoniakgeur, grondwaterdaling, vermest, bodemerosie, voedselverontreiniging, zoutwinning, overbemesting, ammoniakgas, ontzwaveld, verzilting, oppervlaktewater, pesticiden, zoutboringen, waterstanden, grondwaterstand, ammoniakuitstoot, milieuproblemen, verdroging, ontzilting, bodemverstoring, bodemuitputting, grondwaterpeil, bemesting, oppervlaktewateren, overstromingen, rivierafvoer, zwaveldioxide, dichloormethaan, vervuilde, waterstroming, grondwaterwinning, algengroei, grondwaterspiegel, grondwaterstanden, grondverzakkingen, olierampen, milieuramp, rioolslib, lozingskanaal, erosie, ontbossing, overstromingsramp, rookgassen, natuurbranden, schadelijke, bodemdaling, ammonia, chloortoluron, vermesting, rivierafvoeren, afvalgassen, milieubederf, overstromingsgevaar, overstromingsrampen, melklozingen, grondwater, waterbedeffect, verontreinigingsheffing, nitraten, bodemleven, milieucatastrofes
#
# -------------------------------------------------------
#
# Issue:  normenWaarden
# Existing lexicon:
# haat, abortus, antiracist, euthanas, familie, fatsoen, foetus, gezin, huwelijk, levenseinde, normaal, normen, ongeboren_leven, racisme, racist, respect, saamhorigheid, suicid, tolerant, waarden, zelfbeschikking, zelfdoding
#
# New strong:
#
#
# New weak:
#
#
# -------------------------------------------------------
#
# Issue:  ondernemingsklimaat
# Existing lexicon:
# agrarische_sector, bedrijfsinvestering, bedrijfsklimaat, bedrijfsleven, bedrijven, binnenvaart, boeren, bonus, café, deregulering, detailhandel, dienstensector, evenementensector, export, exportsubsidie, exportvergunning, farmaceut, handel, handelsbevordering, handelsoorlog, handelsverdrag, horeca, industrie, intensieve_landbouw, intensieve_vee, internetfirma, investering, invoertarie, kapitalis, kleinbedrijf, koophandel, landbouw, libera, loonsubsidie, maakindustrie, megastal, MKB, multinational, neolibera, omzet, omzetverlies, ondernemers, onderneming, ondernemingsklimaat, ontslagboete, orderporteuille, pharmateuticals, retail, scheepvaart, sportscho, steunmaatregel, steunpakket, steunpot, subsidie, techbedrijven, uitvoer, veestapel, verkoop, verkopen, vermogenspositie, verzekeraar, visser, VNO, vrijhandel, werkgever, winkelier, winst, woningcorporatie, zelfstandigen, zorgondernemer, zorgverzekeraar
#
# New strong:
#
#
# New weak:
#
#
# -------------------------------------------------------
#
# Issue:  ontwikHulp
# Existing lexicon:
# artsen_zonder_grenzen, cordaid, dekolonisatie, derde_wereld, ICTO, kolonialisme, noodhulp, ontwikkelingsh, ontwikkelingslanden, ontwikkelingsorg, ontwikkelingss, unicef
#
# New strong:
# postkoloniale, antikoloniaal, kolonialen, neokoloniaal, neokolonialisme, rekolonisatie, koloniaal, kolonialisten, kolonisator, neokoloniale, koloniale, dekolonialisatie, kolonisatie, prekoloniale, gedekoloniseerde, kolonisering, kolonisators, kolonialisering, vietnamisering, slavenhandel, postkolonialisme, kolonialistische, antikoloniale, postkoloniaal, kolonialistisch
#
# New weak:
# totalitaire, apartheidstijdperk, dekolonisatieproces, isolationistisch, militarisme, imperialist, overheersers, totalitarisme, autoritarisme, imperialistische, serialisme, kapitalisme, heroisme, totalitair, dekoloniseren, isolationistische, kolonisatiepolitiek, imperialisten, kapitalistische, apartheidsstaat, feodaal, perfide, isolationisme, kapitalistisch, mccarthyisme, apartheidsregime, amerikanisme, antikapitalisme, militaristische, antagonisme, barbarisme, roverskapitalisme, dekolonisatiebeleid, oorlogsdenken, antimilitarisme, cultuurimperialisme, abolitionisten, anticommunisme, slavernij, slaventijd, fascisme, gekoloniseerde, imperialisme, feodalisme, appeasement, beschavingsoorlog, militaristisch, apartheidspolitiek, patriottisme, tribalisme, apartheid, globalisme, oorlogszucht, neopatriottisme, wereldcommunisme, imperialistisch, barbarij
#
# -------------------------------------------------------
#
# Issue:  ontwikkelingCrim
# Existing lexicon:
# afluister, afpersing, agressie, bekogel, belagen, bende, bommelding, brandje, brandstichting, cocainehandel, corrupt, criminaliteit, crimine, cybercrime, dealer, drugs, fraud, geplunderd, geteisem, geweld, hack, harddrugs, hooligan, illegaal, illegitiem, ingegooid, kinderhandel, kindermisbruik, losgeld, mensenhandel, mensensmokkel, misdaad, moord, narco, nepotis, onderwereld, onruststoker, onrustzaaier, ontvoering, onwettig, oproerkraaier, paddo, plunder, prostitu, rel, rellen, relschopper, richel, samenscholing, sekswerk, smokkel, softdrugs, tuig, vandalen, vandalisme, veiligheid, verdovende_middel, verniel, vernielzucht, voetbalhooligan, vuurwerk, wapenbezit, wapens, winkeldiefstal, witteboordencriminaliteit, xtc
#
# New strong:
#
#
# New weak:
#
#
# -------------------------------------------------------
#
# Issue:  socZek
# Existing lexicon:
# AOW, arbeider, bestaansminimum, bestaanszekerheid, betalingsregeling, bijstand, buitenschoolse_opvang, Bulgarenaffaire, commissierapport, compensatieregeling, consumentenvertrouwen, deurwaarder, fraude, gemeenschapsgeld, glazen_plafond, huurtoeslag, incassobur, inkomen, inkomensgelijkheid, inkomensverschil, kinderbijslag, kinderopvang, kinderopvangaffair, koopkracht, levensbehoefte, levensonderhoud, meestijg, minimumlo, naschoolse_opvang, Nibud, niveller, ontslag, ontslagen, pensioen, persoonsgebonden_budget, rondkomen, schadevergoeding, schuldeiser, schuldsanering, sociale_zekerheid, tegemoetkomingsregeling, terugvordering, toeslagenaffaire, toeslagendrama, toeslagen-echec, uitkering, uitvoeringsloket, vangnet, verzorgingsstaat, werkende_klasse, werkloosheidsuitkering, werknemersverzekering, wia, ww, zorgtoeslag, zwartwerken
#
# New strong:
#
#
# New weak:
# vergoedingsregeling, compensatieregelingen, vrijstellingsregeling, vergoedingsregelingen
#
# -------------------------------------------------------
#
# Issue:  terreurbestrijding
# Existing lexicon:
# aanslag, Al_Kaida, Al_Qaida, fundamentalis, inkomensongelijkheid, ISIS, jihad, moslimfundamentalis, onthoofding, radicalisme, Samuel_Paty, syrieganger, terreur, terror
#
# New strong:
#
#
# New weak:
#
#
# -------------------------------------------------------
#
# Issue:  vrijheidsrechten
# Existing lexicon:
# #MeToo-beweging, vrijheid, black_lives_matter, BLM, discriminatieverbod, drukpers, gegevensbescherming, gelijke_behandeling, gelijkheidsbeginsel, grondrecht, grondwet, kinderrechten, lgbt, lhbt, meningsuiting, mensenrecht, persvrijheid, privacy, recht_op, rechtsstaat, slavernij, universele_verklaring, verbod_op, vrije_pers, vrijheid_van, vrijheid_van_godsdienst, vrijheid_van_levensovertuiging, vrijheid_van_vergadering, zwarte_piet
#
# New strong:
#
#
# New weak:
# levensbeginsel, grondrechten
#
# -------------------------------------------------------
#
# Issue:  werk
# Existing lexicon:
# arbeid, arbeidsuren, baan, banen, cao, deeltijd, duobaan, flexcontract, flexwerk, lonen, loon, loopbaan, massaontslag, nulurencontract, overwerk, prestatieloon, voltijdbaan, wachtgeld, werk, werkgelegenheid, werkloos, werkloosheid, werklozen, werknemer, werktijdverkorting
#
# New strong:
#
#
# New weak:
#
#
# -------------------------------------------------------
#
# Issue:  woning
# Existing lexicon:
# bouwlocatie, bouwproductie, bouwsector, bouwvergunning, huizenbouw, huurprij, huurverhoging, huurwoning, hypotheekrente, hypotheekrenteaftrek, nieuwbouw, renovatie, starterswoning, woninbouw, woningnood, woningprij, woningrenovatie, woningvoorraad
#
# New strong:
# eenkamerwoningen, nieuwbouwpanden, werkwoningen, huurflats, boerenwoningen, koophuizen, nieuwbouwmarkt, ouderenwoningen, nieuwbouwhuis, bouwkavel, nieuwbouwlocaties, woningbouwlocatie, kapwoningen, eengezinswoning, huurontwikkeling, duplexwoningen, nieuwbouwgebied, loftwoningen, woningen, bouwkavels, vinexwoning, nieuwbouwflat, koopwoning, hoekwoningen, huurwoningmarkt, etagewoningen, laagbouwwoningen, woningbouwlocaties, woningnet, tussenwoningen, luxewoningen, nieuwbouwaanbod, gezinswoningen, hoogbouwwoningen, woningzoekenden, fokuswoningen, woningtypes, bovenwoningen, eengezinswoningen, woonbebouwing, woningbouw, woningblokken, patiowoningen, woningaanbod, koopwoningenmarkt, eensgezinswoning, volkswoningen, schoolwoningen, huurwoningen, woningbouwplan, sloopwoningen, woningverhuurders, woningzoekende, woningbouwmarkt, woningverhuurder, koopwoningen, woninghuren, woningprijs, huurhuizen, woningbouwproject, woningwetwoningen, starterswoningen, eurowoningen, woningtextiel, nieuwbouwwoningen, eensgezinswoningen, woningbouwplannen, nieuwbouwwoning, woningverkoop, stadswoningen, nieuwbouwlocatie, nieuwbouwflats, sloopwoning, buurwoningen, seniorenwoningen, gezinswoning, kluswoningen, huurstroom, woonlocatie, nieuwbouwhuizen, paalwoningen, noodwoningen, woningbestand
#
# New weak:
# koopwoningmarkt, bouwlocaties, woningcomplexen, nieuwbouwappartementen, grondprijs, portiekwoningen, huurprijzen, huizenvoorraad, nieuwbouwprojecten, woningtaxaties, woningbouwcomplexen, waterwoningen, rijtjeswoningen, volkswoningbouw, woningbehoefte, nieuwbouwproject, nieuwbouwontwikkeling, nieuwbouwkosten, woningverkopen, studentenwoningen, huurflat, koophuis, nieuwbouwplannen, woningbouwprojecten, nieuwbouwplan, corporatiewoningen, woningkopers, woningwaarden, massawoningbouw, nieuwbouwkantoren, vinexlocaties, nieuwbouwbuurten, huurhuis, kelderwoningen, nieuwbouwstad, woningprijzen, vinexlocatie, nieuwbouwvleugel, nieuwbouwwijken, zorgwoningen, woonlocaties, renovatiewoningen, doorzonwoningen, bedrijfswoning, woningbouwprogramma, benedenwoningen
#
# -------------------------------------------------------
